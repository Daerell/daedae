# %% [markdown]
# <a href="https://colab.research.google.com/github/Daerell/daedae/blob/main/Weekly_Expenses_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Weekly Expenses Project**

# %%
import pandas as pd

# %%
# Read in you weekly expenses dataset (Make sure it is a csv file)
link ='https://raw.githubusercontent.com/Daerell/daedae/main/Copy%20of%20Weekly%20Expenses_daerell%20caraway%201.1%20-%20Sheet1.csv'
df=pd.read_csv(link)
df
# Out:
#        Date Day of the Week  Amount       Description  \
# 0    2-1-23       Wednesday  300.00           jordans
# 1   1-27-23          Friday   32.91     hair products
# 2   1-27-23          Friday    2.50             takis
# 3   1-26-23        Thursday    7.50        sandwhich
# 4   1-24-23         Tuesday   25.00  playstation plus
# 5       NaN         Tuesday    8.68     hair products
# 6       NaN         Tuesday   18.99           white t
# 7       NaN         Tuesday   20.00         tank tops
# 8       NaN         Tuesday    2.50            sprite
# 9       NaN         Tuesday   10.19      dove shampoo
# 10      NaN         Tuesday    7.49        beef jerky
# 11      NaN         Tuesday   89.99   cookies sweater
#
#                        Category  Method of Payment
# 0   Entertainment and Recreation              Cash
# 1                        Housing             Debit
# 2                           Food              Cash
# 3                           Food              Cash
# ...
